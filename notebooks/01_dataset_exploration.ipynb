# %%
import sys
from pathlib import Path

import numpy as np
import pandas as pd

sys.path.append(str(Path().resolve().parent / "src"))
from utils import quick_overview

# %%
def load_all_csvs(folder_path: str = "data"):
    folder = Path.cwd().parent / folder_path
    csv_files = list(folder.glob("*.csv"))
    dfs = {f.stem: pd.read_csv(f) for f in csv_files}
    return dfs

# %%
dfs = load_all_csvs()
dfs.keys()
# Out:
# dict_keys(['geocode', 'exams', 'economic_ZCTAs', 'transactional', 'demographic_ZCTAs'])

# %%
for name, df in dfs.items():
    quick_overview(df, name)
# Out:
# <h3 style='color:#333;font-weight:bold;'>📋 Overview de <code>geocode</code></h3>
# <hr>
# <b>🔹 Shape:</b>
# (119, 5)
# <b>🔹 Primeiras linhas:</b>
#    Unnamed: 0 Lab Id                                            Address  \
# 0           0   L152      3800 PLEASANT HILL RD STE 1, DULUTH, GA 30096
# 1           1   L520                    1614 N JAMES ST, ROME, NY 13440
# 2           2   L141     12911 120TH AVE NE STE D60, KIRKLAND, WA 98034
# 3           3   L524  5667 PEACHTREE DUNWOODY RD 250, ATLANTA, GA 30342
# 4           4   L545                 1204 IL HWY 164, OQUAWKA, IL 61469
#
#                   Location  Zipcode
# 0    34.000319,-84.1629724  30096.0
# 1   43.2311327,-75.4445363  13440.0
# 2  47.7162786,-122.1838152  98034.0
# 3   33.9093875,-84.3529096  30342.0
# 4   40.9309925,-90.9437598  61469.0
# <b>🔹 Info:</b>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ...
